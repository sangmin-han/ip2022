# %%
import cv2
import numpy as np
img = cv2.imread('zzz.jpg')

res = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)

#OR
height, width = img.shape[:2]
res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)

# %%
img = cv2.imwrite('zzz.jpg',res)

# %%
import cv2
import numpy as np
img = cv2.imread('xxx.jpg',0)
rows,cols = img.shape
M = np.float32([[1,0,100],[0.5,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))

# %%
img = cv2.imread('xxx.jpg',0)
rows,cols = img.shape
M = cv2.getRotationMatrix2D((cols/2,rows/2),60,1)
dst = cv2.warpAffine(img,M,(cols,rows))

# %%
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

# %%
img = cv2.imread('xxx.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[50,50],[200,50],[60,200]])
pts2 = np.float32([[20,100],[200,50],[100,250]])

M = cv2.getAffineTransform(pts1,pts2)

dst = cv2.warpAffine(img,M,(cols,rows))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('ccc.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[324,348],[3539,353],[258,2502],[3600,2500]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(300,300))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('lena.png')
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
