# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
im = cv2.imread('hand.jpg')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,127,255,0)

plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(imgray,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(thresh,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()
img1 = im.copy()
img0 = cv2.drawContours(img0, contours, -1, (0,255,0), 3)
img1 = cv2.drawContours(img1, contours, -1, (0,255,0), 10)

# %%
plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(img0,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(img1,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()
img1 = im.copy()
img0 = cv2.drawContours(img0, contours, -1, (255,0,0), 3)
img1 = cv2.drawContours(img1, contours, 3, (0,255,0), 3)

# %%
print(contours)
# Out:
# (array([[[  0,   0]],
#
#        [[  0, 405]],
#
#        [[645, 405]],
#
#        [[645,   0]]], dtype=int32), array([[[470, 347]],
#
#        [[471, 346]],
#
#        [[472, 347]],
#
#        [[472, 348]],
#
#        [[471, 349]],
#
#        [[470, 348]]], dtype=int32), array([[[469, 345]],
#
#        [[470, 344]],
#
#        [[471, 345]],
#
#        [[471, 346]],
#
#        [[470, 347]],
#
#        [[469, 346]]], dtype=int32), array([[[467, 341]],
#
#        [[468, 340]],
#
#        [[469, 341]],
#
#        [[468, 342]]], dtype=int32), array([[[466, 340]],
#
#        [[467, 339]],
#
#        [[468, 340]],
#
#        [[467, 341]]], dtype=int32), array([[[465, 339]],
#
#        [[466, 338]],
#
#        [[467, 339]],
#
#        [[466, 340]]], dtype=int32), array([[[463, 337]],
#
#        [[464, 336]],
#
#        [[465, 337]],
#
#        [[464, 338]]], dtype=int32), array([[[460, 335]],
#
#        [[461, 334]],
#
#        [[462, 334]],
#
#        [[464, 336]],
#
#        [[463, 337]],
#
#        [[462, 337]]], dtype=int32), array([[[377, 329]],
#
#        [[378, 328]],
#
#        [[380, 328]],
#
#        [[381, 329]],
#
#        [[380, 330]],
#
#        [[378, 330]]], dtype=int32), array([[[383, 327]],
#
#        [[384, 326]],
#
#        [[387, 326]],
#
#        [[388, 327]],
#
#        [[387, 328]],
#
#        [[386, 328]],
#
#        [[385, 329]],
#
#        [[381, 329]],
#
#        [[380, 328]],
#
#        [[381, 327]]], dtype=int32), array([[[409, 321]],
#
#        [[410, 320]],
#
#        [[415, 320]],
#
#        [[416, 321]],
#
#        [[420, 321]],
#
#        [[422, 323]],
#
#        [[426, 323]],
#
#        [[427, 324]],
#
#        [[431, 324]],
#
#        [[432, 325]],
#
#        [[435, 325]],
#
#        [[436, 326]],
#
#        [[439, 326]],
#
#        [[440, 327]],
#
#        [[442, 327]],
#
#        [[443, 328]],
#
#        [[445, 328]],
#
#        [[446, 329]],
#
#        [[447, 329]],
#
#        [[448, 330]],
#
#        [[451, 330]],
#
#        [[452, 331]],
#
#        [[454, 331]],
#
#        [[455, 332]],
#
#        [[459, 332]],
#
#        [[461, 334]],
#
#        [[460, 335]],
#
#        [[462, 337]],
#
#        [[462, 338]],
#
#        [[463, 339]],
#
#        [[462, 340]],
#
#        [[460, 340]],
#
#        [[459, 339]],
#
#        [[457, 339]],
#
#        [[456, 338]],
#
#        [[451, 338]],
#
#        [[450, 339]],
#
#        [[439, 339]],
#
#        [[438, 338]],
#
#        [[435, 338]],
#
#        [[434, 337]],
#
#        [[432, 337]],
#
#        [[431, 336]],
#
#        [[430, 336]],
#
#        [[429, 335]],
#
#        [[422, 335]],
#
#        [[421, 334]],
#
#        [[420, 335]],
#
#        [[419, 335]],
#
#        [[418, 334]],
#
#        [[412, 334]],
#
#        [[411, 333]],
#
#        [[408, 333]],
#
#        [[407, 332]],
#
#        [[402, 332]],
#
#        [[401, 331]],
#
#        [[394, 331]],
#
#        [[393, 330]],
#
#        [[392, 330]],
#
#        [[389, 327]],
#
#        [[388, 327]],
#
#        [[387, 326]],
#
#        [[388, 325]],
#
#        [[389, 325]],
#
#        [[390, 324]],
#
#        [[391, 324]],
#
#        [[392, 323]],
#
#        [[397, 323]],
#
#        [[398, 322]],
#
#        [[401, 322]],
#
#        [[402, 321]]], dtype=int32), array([[[458, 334]]], dtype=int32), array([[[403, 323]],
#
#        [[402, 324]],
#
#        [[400, 324]],
#
#        [[402, 324]],
#
#        [[403, 323]],
#
#        [[404, 323]]], dtype=int32), array([[[441, 286]],
#
#        [[442, 285]],
#
#        [[464, 285]],
#
#        [[465, 286]],
#
#        [[468, 286]],
#
#        [[469, 287]],
#
#        [[468, 288]],
#
#        [[466, 288]],
#
#        [[465, 289]],
#
#        [[464, 289]],
#
#        [[463, 290]],
#
#        [[461, 290]],
#
#        [[460, 291]],
#
#        [[458, 291]],
#
#        [[457, 292]],
#
#        [[454, 292]],
#
#        [[453, 293]],
#
#        [[452, 293]],
#
#        [[451, 294]],
#
#        [[450, 294]],
#
#        [[449, 295]],
#
#        [[447, 295]],
#
#        [[446, 296]],
#
#        [[441, 296]],
#
#        [[440, 297]],
#
#        [[439, 297]],
#
#        [[438, 296]],
#
#        [[431, 296]],
#
#        [[430, 295]],
#
#        [[429, 296]],
#
#        [[421, 296]],
#
#        [[420, 297]],
#
#        [[413, 297]],
#
#        [[412, 298]],
#
#        [[406, 298]],
#
#        [[405, 299]],
#
#        [[404, 299]],
#
#        [[403, 298]],
#
#        [[400, 298]],
#
#        [[400, 299]],
#
#        [[399, 300]],
#
#        [[398, 300]],
#
#        [[397, 301]],
#
#        [[394, 301]],
#
#        [[396, 301]],
#
#        [[397, 302]],
#
#        [[396, 303]],
#
#        [[395, 303]],
#
#        [[394, 304]],
#
#        [[394, 305]],
#
#        [[392, 307]],
#
#        [[391, 307]],
#
#        [[390, 308]],
#
#        [[389, 308]],
#
#        [[388, 309]],
#
#        [[386, 309]],
#
#        [[385, 310]],
#
#        [[384, 310]],
#
#        [[382, 312]],
#
#        [[376, 312]],
#
#        [[375, 311]],
#
#        [[374, 311]],
#
#        [[373, 310]],
#
#        [[373, 309]],
#
#        [[372, 308]],
#
#        [[373, 307]],
#
#        [[372, 308]],
#
#        [[371, 308]],
#
#        [[370, 307]],
#
#        [[372, 305]],
#
#        [[373, 305]],
#
#        [[374, 304]],
#
#        [[376, 304]],
#
#        [[377, 303]],
#
#        [[379, 303]],
#
#        [[380, 302]],
#
#        [[382, 302]],
#
#        [[383, 301]],
#
#        [[384, 301]],
#
#        [[385, 300]],
#
#        [[386, 300]],
#
#        [[387, 299]],
#
#        [[389, 299]],
#
#        [[390, 298]],
#
#        [[391, 298]],
#
#        [[392, 297]],
#
#        [[393, 297]],
#
#        [[394, 296]],
#
#        [[395, 296]],
#
#        [[396, 295]],
#
#        [[398, 295]],
#
#        [[399, 294]],
#
#        [[400, 294]],
#
#        [[401, 293]],
#
#        [[402, 293]],
#
#        [[403, 294]],
#
#        [[402, 295]],
#
#        [[403, 294]],
#
#        [[404, 294]],
#
#        [[405, 293]],
#
#        [[406, 293]],
#
#        [[407, 292]],
#
#        [[409, 292]],
#
#        [[410, 291]],
#
#        [[411, 292]],
#
#        [[413, 290]],
#
#        [[417, 290]],
#
#        [[418, 289]],
#
#        [[422, 289]],
#
#        [[423, 288]],
#
#        [[425, 288]],
#
#        [[426, 287]],
#
#        [[430, 287]],
#
#        [[431, 288]],
#
#        [[432, 287]],
#
#        [[434, 287]],
#
#        [[435, 286]]], dtype=int32), array([[[278, 283]],
#
#        [[279, 282]],
#
#        [[280, 283]],
#
#        [[279, 284]]], dtype=int32), array([[[276, 281]],
#
#        [[277, 280]],
#
#        [[278, 281]],
#
#        [[277, 282]]], dtype=int32), array([[[182, 155]],
#
#        [[183, 154]],
#
#        [[184, 155]],
#
#        [[183, 156]]], dtype=int32), array([[[261, 107]],
#
#        [[268, 107]],
#
#        [[270, 109]],
#
#        [[271, 109]],
#
#        [[272, 110]],
#
#        [[271, 111]],
#
#        [[273, 113]],
#
#        [[271, 115]],
#
#        [[269, 115]],
#
#        [[268, 116]],
#
#        [[265, 116]],
#
#        [[264, 117]],
#
#        [[262, 117]],
#
#        [[261, 118]],
#
#        [[260, 118]],
#
#        [[259, 119]],
#
#        [[257, 119]],
#
#        [[256, 120]],
#
#        [[255, 120]],
#
#        [[254, 121]],
#
#        [[252, 121]],
#
#        [[251, 122]],
#
#        [[250, 122]],
#
#        [[249, 123]],
#
#        [[248, 123]],
#
#        [[247, 124]],
#
#        [[245, 124]],
#
#        [[244, 125]],
#
#        [[243, 125]],
#
#        [[242, 126]],
#
#        [[241, 126]],
#
#        [[240, 125]],
#
#        [[239, 126]],
#
#        [[236, 126]],
#
#        [[235, 127]],
#
#        [[232, 127]],
#
#        [[231, 128]],
#
#        [[229, 128]],
#
#        [[228, 129]],
#
#        [[226, 129]],
#
#        [[225, 130]],
#
#        [[224, 130]],
#
#        [[223, 131]],
#
#        [[222, 130]],
#
#        [[220, 130]],
#
#        [[219, 131]],
#
#        [[218, 131]],
#
#        [[217, 132]],
#
#        [[214, 132]],
#
#        [[213, 131]],
#
#        [[212, 132]],
#
#        [[209, 132]],
#
#        [[208, 133]],
#
#        [[205, 133]],
#
#        [[204, 134]],
#
#        [[195, 134]],
#
#        [[194, 135]],
#
#        [[179, 135]],
#
#        [[178, 134]],
#
#        [[176, 134]],
#
#        [[175, 133]],
#
#        [[176, 132]],
#
#        [[178, 132]],
#
#        [[179, 131]],
#
#        [[181, 131]],
#
#        [[182, 130]],
#
#        [[183, 130]],
#
#        [[184, 129]],
#
#        [[186, 129]],
#
#        [[187, 128]],
#
#        [[188, 128]],
#
#        [[189, 127]],
#
#        [[191, 127]],
#
#        [[192, 126]],
#
#        [[193, 126]],
#
#        [[195, 124]],
#
#        [[197, 124]],
#
#        [[198, 123]],
#
#        [[201, 123]],
#
#        [[202, 122]],
#
#        [[206, 122]],
#
#        [[207, 123]],
#
#        [[214, 123]],
#
#        [[215, 122]],
#
#        [[216, 123]],
#
#        [[217, 122]],
#
#        [[218, 123]],
#
#        [[219, 123]],
#
#        [[220, 122]],
#
#        [[223, 122]],
#
#        [[224, 121]],
#
#        [[225, 122]],
#
#        [[227, 122]],
#
#        [[228, 121]],
#
#        [[234, 121]],
#
#        [[235, 120]],
#
#        [[240, 120]],
#
#        [[241, 121]],
#
#        [[242, 121]],
#
#        [[243, 120]],
#
#        [[244, 120]],
#
#        [[245, 119]],
#
#        [[246, 119]],
#
#        [[248, 117]],
#
#        [[248, 116]],
#
#        [[253, 111]],
#
#        [[254, 111]],
#
#        [[256, 109]],
#
#        [[259, 109]]], dtype=int32), array([[[255,  92]],
#
#        [[256,  91]],
#
#        [[257,  91]],
#
#        [[258,  92]],
#
#        [[257,  93]],
#
#        [[256,  93]]], dtype=int32), array([[[257,  91]],
#
#        [[258,  90]],
#
#        [[262,  90]],
#
#        [[263,  91]],
#
#        [[262,  92]],
#
#        [[258,  92]]], dtype=int32), array([[[262,  90]],
#
#        [[263,  89]],
#
#        [[266,  89]],
#
#        [[267,  90]],
#
#        [[266,  91]],
#
#        [[263,  91]]], dtype=int32), array([[[179,  85]],
#
#        [[180,  84]],
#
#        [[181,  85]],
#
#        [[180,  86]]], dtype=int32), array([[[178,  84]],
#
#        [[179,  83]],
#
#        [[180,  84]],
#
#        [[179,  85]]], dtype=int32), array([[[181,  83]],
#
#        [[182,  82]],
#
#        [[185,  82]],
#
#        [[186,  83]],
#
#        [[193,  83]],
#
#        [[194,  82]],
#
#        [[206,  82]],
#
#        [[207,  83]],
#
#        [[208,  82]],
#
#        [[209,  83]],
#
#        [[212,  83]],
#
#        [[213,  84]],
#
#        [[215,  84]],
#
#        [[216,  85]],
#
#        [[218,  85]],
#
#        [[219,  84]],
#
#        [[221,  84]],
#
#        [[222,  85]],
#
#        [[223,  85]],
#
#        [[224,  84]],
#
#        [[227,  84]],
#
#        [[228,  85]],
#
#        [[233,  85]],
#
#        [[234,  86]],
#
#        [[238,  86]],
#
#        [[239,  87]],
#
#        [[244,  87]],
#
#        [[245,  88]],
#
#        [[251,  88]],
#
#        [[256,  93]],
#
#        [[255,  94]],
#
#        [[254,  94]],
#
#        [[253,  95]],
#
#        [[248,  95]],
#
#        [[247,  96]],
#
#        [[243,  96]],
#
#        [[242,  97]],
#
#        [[235,  97]],
#
#        [[234,  98]],
#
#        [[229,  98]],
#
#        [[228,  97]],
#
#        [[223,  97]],
#
#        [[222,  96]],
#
#        [[220,  96]],
#
#        [[219,  95]],
#
#        [[214,  95]],
#
#        [[213,  94]],
#
#        [[208,  94]],
#
#        [[207,  93]],
#
#        [[204,  93]],
#
#        [[203,  92]],
#
#        [[200,  92]],
#
#        [[199,  91]],
#
#        [[195,  91]],
#
#        [[194,  90]],
#
#        [[192,  90]],
#
#        [[191,  89]],
#
#        [[190,  90]],
#
#        [[189,  90]],
#
#        [[188,  89]],
#
#        [[185,  89]],
#
#        [[184,  88]],
#
#        [[183,  88]],
#
#        [[182,  87]],
#
#        [[181,  87]],
#
#        [[180,  86]],
#
#        [[181,  85]],
#
#        [[182,  85]],
#
#        [[182,  84]]], dtype=int32), array([[[242,  94]],
#
#        [[243,  94]]], dtype=int32), array([[[177,  83]],
#
#        [[178,  82]],
#
#        [[179,  83]],
#
#        [[178,  84]]], dtype=int32), array([[[176,  82]],
#
#        [[177,  81]],
#
#        [[178,  82]],
#
#        [[177,  83]]], dtype=int32), array([[[175,  81]],
#
#        [[176,  80]],
#
#        [[177,  81]],
#
#        [[176,  82]]], dtype=int32), array([[[174,  80]],
#
#        [[175,  79]],
#
#        [[176,  80]],
#
#        [[175,  81]]], dtype=int32), array([[[173,  77]],
#
#        [[174,  76]],
#
#        [[175,  77]],
#
#        [[175,  78]],
#
#        [[174,  79]],
#
#        [[173,  78]]], dtype=int32), array([[[172,  75]],
#
#        [[173,  74]],
#
#        [[174,  75]],
#
#        [[174,  76]],
#
#        [[173,  77]],
#
#        [[172,  76]]], dtype=int32))

# %%
im = cv2.imread('hand.jpg')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imgray,250,255,0)
#thresh = cv2.adaptiveThreshold(imgray,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
 
plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(imgray,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(thresh,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()
img1 = im.copy()

# %%
img0 = cv2.drawContours(img0, contours, 2, (255,0,0), 3)
img1 = cv2.drawContours(img1, contours, 3, (255,0,0), 3)

# %%
cnt = contours[2]
M = cv2.moments(cnt)
print(M)
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])
img0 = cv2.rectangle(img0, (cx-2,cy-2),(cx+2,cy+2),(0,0,255),2)
area = cv2.contourArea(cnt)
perimeter = cv2.arcLength(cnt,True)
epsilon = 0.1*cv2.arcLength(cnt,True)
approx = cv2.approxPolyDP(cnt,epsilon,True)
# Out:
# {'m00': 0.0, 'm10': 0.0, 'm01': 0.0, 'm20': 0.0, 'm11': 0.0, 'm02': 0.0, 'm30': 0.0, 'm21': 0.0, 'm12': 0.0, 'm03': 0.0, 'mu20': 0.0, 'mu11': 0.0, 'mu02': 0.0, 'mu30': 0.0, 'mu21': 0.0, 'mu12': 0.0, 'mu03': 0.0, 'nu20': 0.0, 'nu11': 0.0, 'nu02': 0.0, 'nu30': 0.0, 'nu21': 0.0, 'nu12': 0.0, 'nu03': 0.0}
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\U3\Chap149.ipynb 셀 11 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/U3/Chap149.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a> M = cv2.moments(cnt)
#       <a href='vscode-notebook-cell:/c%3A/Users/U3/Chap149.ipynb#X50sZmlsZQ%3D%3D?line=2'>3</a> print(M)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/U3/Chap149.ipynb#X50sZmlsZQ%3D%3D?line=3'>4</a> cx = int(M['m10']/M['m00'])
#       <a href='vscode-notebook-cell:/c%3A/Users/U3/Chap149.ipynb#X50sZmlsZQ%3D%3D?line=4'>5</a> cy = int(M['m01']/M['m00'])
#       <a href='vscode-notebook-cell:/c%3A/Users/U3/Chap149.ipynb#X50sZmlsZQ%3D%3D?line=5'>6</a> img0 = cv2.rectangle(img0, (cx-2,cy-2),(cx+2,cy+2),(0,0,255),2)
#
# ZeroDivisionError: float division by zero

# %%
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()
img1 = im.copy()
img0 = cv2.drawContours(img0, contours, -1, (255,0,0), 3)
img1 = cv2.drawContours(img1, contours, -11, (0,255,0), 3)

plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(img0,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(img1,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
im = cv2.imread('hand.jpg')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
imgray = cv2.GaussianBlur(imgray,(5,5),0)
ret, thresh = cv2.threshold(imgray,240,255,0)
#thresh = cv2.adaptiveThreshold(imgray,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, #cv2.THRESH_BINARY, 11, 2)
 
kernel = np.ones((5,5),np.uint8)

plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(imgray,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(thresh,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()

# %%
img1 = im.copy()
img0 = cv2.drawContours(img0, contours, 2, (255,0,0), 3)
img1 = cv2.drawContours(img1, contours, 3, (255,0,0), 3)

# %%
cnt = contours[2]
M = cv2.moments(cnt)
print(M)
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])
img0 = cv2.rectangle(img0, (cx-2,cy-2),(cx+2,cy+2),(0,0,255),2)
 
size = []
for i in range(len(contours)):
    size.append((i, contours[i].shape[0]))
# Out:
# {'m00': 681.0, 'm10': 30552.833333333332, 'm01': 194165.16666666666, 'm20': 1751950.0, 'm11': 8584479.75, 'm02': 55406798.0, 'm30': 110157209.15, 'm21': 488864168.23333335, 'm12': 2413402349.633333, 'm03': 15824213470.45, 'mu20': 381207.5261461905, 'mu11': -126674.40022842214, 'mu02': 46868.56285691261, 'mu30': -2648923.569305524, 'mu21': 718588.1068887115, 'mu12': -170561.91169374948, 'mu03': 27489.872303009033, 'nu20': 0.8219913406823568, 'nu11': -0.27314586657442547, 'nu02': 0.1010618893285822, 'nu30': -0.21887776619934723, 'nu21': 0.059376178865913544, 'nu12': -0.014093351224930096, 'nu03': 0.002271459211775369}

# %%
print(len(contours))
# Out:
# 11

# %%
print(size)
# Out:
# [(0, 2), (1, 2), (2, 110), (3, 5), (4, 62), (5, 2), (6, 7), (7, 49), (8, 85), (9, 6), (10, 1139)]
