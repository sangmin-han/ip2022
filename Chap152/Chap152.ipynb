# %%
import cv2
import numpy as np

# %%
filename = 'im1.png'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

# %%
def nothing(x):
    pass
 
cv2.namedWindow('image')
cv2.createTrackbar('threshold', 'image', 10, 1000, nothing)
while(1):
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
    threshold = cv2.getTrackbarPos('threshold', 'image')
    if(threshold <= 1):
        threshold=1
    img = cv2.imread(filename)
    img[dst>1./threshold*dst.max()]=[0,0,255]
    cv2.imshow('image',img)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\u303\Chap152.ipynb 셀 3 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> if k == 27:
#       <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>     break
# ---> <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> threshold = cv2.getTrackbarPos('threshold', 'image')
#      <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> if(threshold <= 1):
#      <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>     threshold=1
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2581: error: (-27:Null pointer) NULL window: 'image' in function 'cvGetTrackbarPos'

# %%
from matplotlib import pyplot as plt

# %%
sift = cv2.SIFT_create()
kp = sift.detect(gray,None)
imgsift = cv2.imread('im1.png')
imgsift=cv2.drawKeypoints(img,kp,imgsift,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\u303\Chap152.ipynb 셀 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> sift = cv2.SIFT_create()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> kp = sift.detect(gray,None)
#       <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> imgsift = cv2.imread('im1.png')
#       <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> imgsift=cv2.drawKeypoints(img,kp,imgsift,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\features2d\src\sift.dispatch.cpp:477: error: (-5:Bad argument) image is empty or has incorrect depth (!=CV_8U) in function 'cv::SIFT_Impl::detectAndCompute'

# %%
plt.figure(figsize = (30,45))
plt.subplot(1,2,1),plt.imshow(img,cmap = 'gray')
plt.title('img'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(imgsift,cmap = 'gray')
plt.title('imgsift'), plt.xticks([]), plt.yticks([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\u303\Chap152.ipynb 셀 6 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> plt.subplot(1,2,1),plt.imshow(img,cmap = 'gray')
#       <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> plt.title('img'), plt.xticks([]), plt.yticks([])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> plt.subplot(1,2,2),plt.imshow(imgsift,cmap = 'gray')
#       <a href='vscode-notebook-cell:/c%3A/Users/u303/Chap152.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> plt.title('imgsift'), plt.xticks([]), plt.yticks([])
#
# NameError: name 'imgsift' is not defined

# %%
plt.show()
